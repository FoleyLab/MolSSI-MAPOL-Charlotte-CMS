# %% [markdown]
# # Formaldehyde Polariton Project
# ## Sydney Rosenkrantz, Leonel Kachie, Katherinn Sanabria, Gustavo Sanchez, Maya Younis

# %%
import psi4
import numpy as np
from scipy.interpolate import InterpolatedUnivariateSpline
from numpy import linalg as LA
from psi4.driver.procrouting.response.scf_response import tdscf_excitations
from matplotlib import pyplot as plt

# %%
# set basis set
psi4.set_options({
    'basis':'cc-pVDZ'
})

# set the number of electronic states... this is the ground state + n_states more
# we will get 2 excited-state
n_states = 2

# set the number of bond lengths to compute the stretch along
n_geoms = 25

# initialize geometry list
geoms = []

# initialize energy list... note
# there will be the ground state energy + n_states excited state energies
Es = np.zeros((n_states+1, n_geoms))

# initialize z-component of transition dipole list
mu_z = np.zeros((n_states, n_geoms))

# generate bond lengths
rs = []
for i in range(0,n_geoms):
    rs.append(1.1 + i*0.1)

# loop over bond lengths
ctr = 0
for i in rs:
    # generate the formaldehyde molecule using a z-matrix and set the C=O bond length
    mol = psi4.geometry("""
    C
    O 1 """ + str(i) + """
    H1 1 1.36 2 120
    H2 1 1.36 2 120 3 180
    symmetry c1
    0 1
    """)
    # save the geometry
    geoms.append(mol.geometry().to_array())
    psi4.set_options({
    'save_jk': True,
    })  
   
    # calculate and save the ground-state energy and wavefunction
    e, wfn = psi4.energy("b3lyp/cc-pVDZ", return_wfn=True, molecule=mol)
    
    # calculate the excited-state energies and save them to a dictionary called 'res'
    res = tdscf_excitations(wfn, states=n_states, triplets = "NONE")
    
    # parse the excitation energies from the 'res' dictionary 
    delta_e = [r["EXCITATION ENERGY"] for r in res]
    
    # parse the transition dipole moment from the 'res' dictionary
    mu = [r["ELECTRIC DIPOLE TRANSITION MOMENT (LEN)"] for r in res]
    Es[0,ctr] = e
    
    # store the results to the respective arrays
    for j in range(0, n_states):
        Es[j+1,ctr] = e + delta_e[j]
        # we only want the z-component which is index 2
        mu_z[j,ctr] = np.absolute(mu[j][2])

    
    # increment the counter!
    ctr += 1
# Out:
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
#
# *** tstart() called on 5536536a3eb7
# *** at Fri Jun 23 04:22:46 2023
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry C          line   138 file /usr/local/psi4/share/psi4/basis/cc-pvdz.gbs
#     atoms 2   entry O          line   198 file /usr/local/psi4/share/psi4/basis/cc-pvdz.gbs
#     atoms 3-4 entry H          line    22 file /usr/local/psi4/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C            0.000000000000     0.000000000000    -0.540601758364    12.000000000000
#          O            0.000000000000     0.000000000000     0.559398241636    15.994914619570
#          H            0.000000000000     1.177794549147    -1.220601758364     1.007825032230
#          H            0.000000000000    -1.177794549147    -1.220601758364     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      6.02896  B =      1.46393  C =      1.17792 [cm^-1]
#   Rotational constants: A = 180743.62258  B =  43887.65723  C =  35313.04349 [MHz]
#   Nuclear repulsion =   31.952100621809699
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 16
#   Nalpha       = 8
#   Nbeta        = 8
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-06
#   Density threshold  = 1.00e-06
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 18
#     Number of basis functions: 38
#     Number of Cartesian functions: 40
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 5.1.5
#     S. Lehtola, C. Steigemann, M. J. Oliveira, and M. A. Marques, SoftwareX 7, 1 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: B3LYP <=
#
#     B3LYP Hyb-GGA Exchange-Correlation Functional
#
#     P. J. Stephens, F. J. Devlin, C. F. Chabalowski, and M. J. Frisch, J. Phys. Chem. 98, 11623 (1994) (10.1021/j100096a001)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     0.0800   Slater exchange
#     0.7200         Becke 88
#
#    => Exact (HF) Exchange <=
#
#     0.2000               HF
#
#    => Correlation Functionals <=
#
#     0.1900   Vosko, Wilk & Nusair (VWN5_RPA)
#     0.8100   Lee, Yang & Parr
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_B3LYP:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =          87433
#     Total Blocks           =            714
#     Max Points             =            256
#     Max Functions          =             38
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1   entry C          line   121 file /usr/local/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 2   entry O          line   221 file /usr/local/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 3-4 entry H          line    51 file /usr/local/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.002 GiB; user supplied 0.272 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               278
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (CC-PVDZ AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 66
#     Number of basis functions: 186
#     Number of Cartesian functions: 212
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Cached 100.0% of DFT collocation blocks in 0.094 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 1.8623316014E-02.
#   Reciprocal condition number of the overlap matrix is 5.0919643342E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         38      38
#    -------------------------
#     Total      38      38
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:  -114.09938501485757   -1.14099e+02   0.00000e+00
#    @DF-RKS iter   1:  -114.32857042031434   -2.29185e-01   1.41331e-02 DIIS
#    @DF-RKS iter   2:  -114.09176589987689    2.36805e-01   2.45523e-02 DIIS
#    @DF-RKS iter   3:  -114.44209892147468   -3.50333e-01   3.80815e-03 DIIS
#    @DF-RKS iter   4:  -114.45132261609378   -9.22369e-03   8.34054e-04 DIIS
#    @DF-RKS iter   5:  -114.45185888343046   -5.36267e-04   1.13472e-04 DIIS
#    @DF-RKS iter   6:  -114.45186894143897   -1.00580e-05   8.32926e-06 DIIS
#    @DF-RKS iter   7:  -114.45186898305219   -4.16132e-08   6.60405e-07 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =   16.0000002297 ; deviation = 2.297e-07
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -19.179233     2A    -10.314129     3A     -1.142608
#        4A     -0.574280     5A     -0.494062     6A     -0.468265
#        7A     -0.453117     8A     -0.263396
#
#     Virtual:
#
#        9A     -0.017390    10A      0.001384    11A      0.114476
#       12A      0.218337    13A      0.408345    14A      0.435602
#       15A      0.492707    16A      0.582020    17A      0.682527
#       18A      0.794365    19A      0.844418    20A      0.919825
#       21A      0.961965    22A      1.032041    23A      1.213745
#       24A      1.247584    25A      1.284039    26A      1.517445
#       27A      1.535970    28A      1.544692    29A      1.587267
#       30A      1.691100    31A      1.960042    32A      2.129505
#       33A      2.298801    34A      2.650061    35A      2.760226
#       36A      3.102530    37A      3.286393    38A      3.539951
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     8 ]
#
#   @DF-RKS Final Energy:  -114.45186898305219
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             31.9521006218096986
#     One-Electron Energy =                -218.5057449358095596
#     Two-Electron Energy =                  83.9612598181616221
#     DFT Exchange-Correlation Energy =     -11.8594844872139600
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                       -114.4518689830521936
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:    -2.2859
#
#   Electronic Dipole Moment: [e a0]
#      X:     0.0000      Y:    -0.0000      Z:     1.8509
#
#   Dipole Moment: [e a0]
#      X:     0.0000      Y:    -0.0000      Z:    -0.4350     Total:     0.4350
#
#   Dipole Moment: [D]
#      X:     0.0000      Y:    -0.0000      Z:    -1.1056     Total:     1.1056
#
#
# *** tstop() called on 5536536a3eb7 at Fri Jun 23 04:22:48 2023
# Module time:
# 	user time   =       1.46 seconds =       0.02 minutes
# 	system time =       0.07 seconds =       0.00 minutes
# 	total time  =          2 seconds =       0.03 minutes
# Total time:
# 	user time   =      75.53 seconds =       1.26 minutes
# 	system time =      27.68 seconds =       0.46 minutes
# 	total time  =      31766 seconds =     529.43 minutes
#
#
#          ---------------------------------------------------------
#                          TDSCF excitation energies
#                  by Andrew M. James and Daniel G. A. Smith
#          ---------------------------------------------------------
#
#   ==> Options <==
#
#      Residual threshold  : 1.0000e-04
#      Initial guess       : denominators
#      Reference           : RHF
#      Solver type         : RPA (Hamiltonian)
#
#
#   ==> Requested Excitations <==
#
#       2 singlet states with A symmetry
#
#
#   ==> Seeking the lowest 2 singlet states with A symmetry
#
#                         Generalized Hamiltonian Solver
#                               By Andrew M. James
#
#   ==> Options <==
#
#     Max number of iterations        = 60
#     Eigenvector tolerance           = 1.0000e-04
#     Max number of expansion vectors = 400
#
#   => Iterations <=
#                               Max[D[value]]     Max[|R|]   # vectors
#   HamiltonianSolver iter   1:   2.69161e-01  1.77080e-01      8
#   HamiltonianSolver iter   2:   1.43144e-02  3.58688e-02     12
#   HamiltonianSolver iter   3:   2.82578e-04  6.91108e-03     16
#   HamiltonianSolver iter   4:   9.10509e-06  1.13402e-03     20
#   HamiltonianSolver iter   5:   1.73260e-07  2.23372e-04     22
#   HamiltonianSolver iter   6:   5.74937e-09  7.76080e-05     24      Converged
#
# ******************************************************************************************
# **********                               WARNING                                **********
# **********  Length-gauge rotatory strengths are **NOT** gauge-origin invariant  **********
# ******************************************************************************************
#
#                                     Excitation Energy         Total Energy        Oscillator Strength             Rotatory Strength
#      #   Sym: GS->ES (Trans)        au              eV              au          au (length)    au (velocity)    au (length)    au (velocity)
#     ---- -------------------- --------------- --------------- --------------- --------------- --------------- --------------- ---------------
#      1        A->A (1 A)       0.17776         4.83702        -114.27411       0.0000          0.0000         -0.0000         -0.0000
#      2        A->A (1 A)       0.25455         6.92678        -114.19731       0.3610          0.3219         -0.0000         -0.0000
#
#
#
# Contributing excitations and de-excitations
# Only contributions with coefficients > 1.00e-01 will be printed:
#
# Excited State    1 (1 A):   0.17776 au   256.32 nm f = 0.0000
#   Sums of squares: Xssq =  1.000821e+00; Yssq =  8.213015e-04; Xssq - Yssq =  1.000000e+00
#      8 ->  9    0.998932 (99.786%)
#
# Excited State    2 (1 A):   0.25455 au   178.99 nm f = 0.3610
#   Sums of squares: Xssq =  1.011618e+00; Yssq =  1.161770e-02; Xssq - Yssq =  1.000000e+00
#      8 -> 10    0.995463 (99.095%)
#
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
#
# *** tstart() called on 5536536a3eb7
# *** at Fri Jun 23 04:22:51 2023
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry C          line   138 file /usr/local/psi4/share/psi4/basis/cc-pvdz.gbs
#     atoms 2   entry O          line   198 file /usr/local/psi4/share/psi4/basis/cc-pvdz.gbs
#     atoms 3-4 entry H          line    22 file /usr/local/psi4/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C            0.000000000000     0.000000000000    -0.593899371348    12.000000000000
#          O            0.000000000000     0.000000000000     0.606100628652    15.994914619570
#          H            0.000000000000     1.177794549147    -1.273899371348     1.007825032230
#          H            0.000000000000    -1.177794549147    -1.273899371348     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      6.02896  B =      1.25996  C =      1.04216 [cm^-1]
#   Rotational constants: A = 180743.62258  B =  37772.65652  C =  31243.28678 [MHz]
#   Nuclear repulsion =   29.877470268126409
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 16
#   Nalpha       = 8
#   Nbeta        = 8
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-06
#   Density threshold  = 1.00e-06
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 18
#     Number of basis functions: 38
#     Number of Cartesian functions: 40
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 5.1.5
#     S. Lehtola, C. Steigemann, M. J. Oliveira, and M. A. Marques, SoftwareX 7, 1 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: B3LYP <=
#
#     B3LYP Hyb-GGA Exchange-Correlation Functional
#
#     P. J. Stephens, F. J. Devlin, C. F. Chabalowski, and M. J. Frisch, J. Phys. Chem. 98, 11623 (1994) (10.1021/j100096a001)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     0.0800   Slater exchange
#     0.7200         Becke 88
#
#    => Exact (HF) Exchange <=
#
#     0.2000               HF
#
#    => Correlation Functionals <=
#
#     0.1900   Vosko, Wilk & Nusair (VWN5_RPA)
#     0.8100   Lee, Yang & Parr
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_B3LYP:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =          87453
#     Total Blocks           =            712
#     Max Points             =            256
#     Max Functions          =             38
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1   entry C          line   121 file /usr/local/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 2   entry O          line   221 file /usr/local/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 3-4 entry H          line    51 file /usr/local/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.002 GiB; user supplied 0.272 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               278
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (CC-PVDZ AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 66
#     Number of basis functions: 186
#     Number of Cartesian functions: 212
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Cached 100.0% of DFT collocation blocks in 0.094 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 2.1089246311E-02.
#   Reciprocal condition number of the overlap matrix is 5.8953671670E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         38      38
#    -------------------------
#     Total      38      38
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:  -113.93726752448910   -1.13937e+02   0.00000e+00
#    @DF-RKS iter   1:  -114.35316527349936   -4.15898e-01   1.34594e-02 DIIS
#    @DF-RKS iter   2:  -113.98243444384610    3.70731e-01   2.80933e-02 DIIS
#    @DF-RKS iter   3:  -114.45384629109019   -4.71412e-01   4.19236e-03 DIIS
#    @DF-RKS iter   4:  -114.46591315471922   -1.20669e-02   1.04022e-03 DIIS
#    @DF-RKS iter   5:  -114.46673343182206   -8.20277e-04   1.63661e-04 DIIS
#    @DF-RKS iter   6:  -114.46675269772220   -1.92659e-05   1.59826e-05 DIIS
#    @DF-RKS iter   7:  -114.46675284919569   -1.51473e-07   9.89421e-07 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =   16.0000000323 ; deviation = 3.233e-08
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -19.177882     2A    -10.325911     3A     -1.078726
#        4A     -0.585428     5A     -0.465775     6A     -0.450413
#        7A     -0.412500     8A     -0.270325
#
#     Virtual:
#
#        9A     -0.046220    10A     -0.005158    11A      0.096172
#       12A      0.208955    13A      0.401774    14A      0.442415
#       15A      0.479646    16A      0.586381    17A      0.630266
#       18A      0.718644    19A      0.858654    20A      0.920075
#       21A      0.968636    22A      1.040307    23A      1.177841
#       24A      1.251666    25A      1.268682    26A      1.475424
#       27A      1.499419    28A      1.521427    29A      1.593738
#       30A      1.681717    31A      1.926700    32A      2.094147
#       33A      2.215020    34A      2.633692    35A      2.704720
#       36A      3.014350    37A      3.187344    38A      3.404801
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     8 ]
#
#   @DF-RKS Final Energy:  -114.46675284919569
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             29.8774702681264088
#     One-Electron Energy =                -214.6826507111984483
#     Two-Electron Energy =                  82.1218469979771584
#     DFT Exchange-Correlation Energy =     -11.7834194041008065
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                       -114.4667528491956858
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:    -2.3856
#
#   Electronic Dipole Moment: [e a0]
#      X:    -0.0000      Y:     0.0000      Z:     1.7228
#
#   Dipole Moment: [e a0]
#      X:    -0.0000      Y:     0.0000      Z:    -0.6627     Total:     0.6627
#
#   Dipole Moment: [D]
#      X:    -0.0000      Y:     0.0000      Z:    -1.6845     Total:     1.6845
#
#
# *** tstop() called on 5536536a3eb7 at Fri Jun 23 04:22:52 2023
# Module time:
# 	user time   =       1.47 seconds =       0.02 minutes
# 	system time =       0.29 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =      79.63 seconds =       1.33 minutes
# 	system time =      29.19 seconds =       0.49 minutes
# 	total time  =      31770 seconds =     529.50 minutes
#
#
#          ---------------------------------------------------------
#                          TDSCF excitation energies
#                  by Andrew M. James and Daniel G. A. Smith
#          ---------------------------------------------------------
#
#   ==> Options <==
#
#      Residual threshold  : 1.0000e-04
#      Initial guess       : denominators
#      Reference           : RHF
#      Solver type         : RPA (Hamiltonian)
#
#
#   ==> Requested Excitations <==
#
#       2 singlet states with A symmetry
#
#
#   ==> Seeking the lowest 2 singlet states with A symmetry
#
#                         Generalized Hamiltonian Solver
#                               By Andrew M. James
#
#   ==> Options <==
#
#     Max number of iterations        = 60
#     Eigenvector tolerance           = 1.0000e-04
#     Max number of expansion vectors = 400
#
#   => Iterations <=
#                               Max[D[value]]     Max[|R|]   # vectors
#   HamiltonianSolver iter   1:   2.60316e-01  1.65737e-01      8
#   HamiltonianSolver iter   2:   1.28391e-02  3.68907e-02     12
#   HamiltonianSolver iter   3:   3.00653e-04  6.93152e-03     16
#   HamiltonianSolver iter   4:   8.92537e-06  1.45370e-03     20
#   HamiltonianSolver iter   5:   3.19416e-07  4.86962e-04     22
#   HamiltonianSolver iter   6:   2.76942e-08  8.33303e-05     24      Converged
#
# ******************************************************************************************
# **********                               WARNING                                **********
# **********  Length-gauge rotatory strengths are **NOT** gauge-origin invariant  **********
# ******************************************************************************************
#
#                                     Excitation Energy         Total Energy        Oscillator Strength             Rotatory Strength
#      #   Sym: GS->ES (Trans)        au              eV              au          au (length)    au (velocity)    au (length)    au (velocity)
#     ---- -------------------- --------------- --------------- --------------- --------------- --------------- --------------- ---------------
#      1        A->A (1 A)       0.15342         4.17478        -114.31333       0.0000          0.0000          0.0000          0.0000
#      2        A->A (1 A)       0.24717         6.72574        -114.21959       0.2537          0.2201          0.0000          0.0000
#
#
#
# Contributing excitations and de-excitations
# Only contributions with coefficients > 1.00e-01 will be printed:
#
# Excited State    1 (1 A):   0.15342 au   296.98 nm f = 0.0000
#   Sums of squares: Xssq =  1.001198e+00; Yssq =  1.197635e-03; Xssq - Yssq =  1.000000e+00
#      8 ->  9    0.998882 (99.776%)
#
# Excited State    2 (1 A):   0.24717 au   184.34 nm f = 0.2537
#   Sums of squares: Xssq =  1.008288e+00; Yssq =  8.288379e-03; Xssq - Yssq =  1.000000e+00
#      5 -> 10    0.117578 ( 1.382%)
#      8 -> 10   -0.993339 (98.672%)
#
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
#
# *** tstart() called on 5536536a3eb7
# *** at Fri Jun 23 04:22:55 2023
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry C          line   138 file /usr/local/psi4/share/psi4/basis/cc-pvdz.gbs
#     atoms 2   entry O          line   198 file /usr/local/psi4/share/psi4/basis/cc-pvdz.gbs
#     atoms 3-4 entry H          line    22 file /usr/local/psi4/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C            0.000000000000     0.000000000000    -0.647196984332    12.000000000000
#          O            0.000000000000     0.000000000000     0.652803015668    15.994914619570
#          H            0.000000000000     1.177794549147    -1.327196984332     1.007825032230
#          H            0.000000000000    -1.177794549147    -1.327196984332     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      6.02896  B =      1.09514  C =      0.92679 [cm^-1]
#   Rotational constants: A = 180743.62258  B =  32831.53104  C =  27784.55150 [MHz]
#   Nuclear repulsion =   28.107833259894942
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 16
#   Nalpha       = 8
#   Nbeta        = 8
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-06
#   Density threshold  = 1.00e-06
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 18
#     Number of basis functions: 38
#     Number of Cartesian functions: 40
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 5.1.5
#     S. Lehtola, C. Steigemann, M. J. Oliveira, and M. A. Marques, SoftwareX 7, 1 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: B3LYP <=
#
#     B3LYP Hyb-GGA Exchange-Correlation Functional
#
#     P. J. Stephens, F. J. Devlin, C. F. Chabalowski, and M. J. Frisch, J. Phys. Chem. 98, 11623 (1994) (10.1021/j100096a001)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     0.0800   Slater exchange
#     0.7200         Becke 88
#
#    => Exact (HF) Exchange <=
#
#     0.2000               HF
#
#    => Correlation Functionals <=
#
#     0.1900   Vosko, Wilk & Nusair (VWN5_RPA)
#     0.8100   Lee, Yang & Parr
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_B3LYP:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =          87490
#     Total Blocks           =            719
#     Max Points             =            256
#     Max Functions          =             38
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1   entry C          line   121 file /usr/local/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 2   entry O          line   221 file /usr/local/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 3-4 entry H          line    51 file /usr/local/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.002 GiB; user supplied 0.273 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               279
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (CC-PVDZ AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 66
#     Number of basis functions: 186
#     Number of Cartesian functions: 212
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Cached 100.0% of DFT collocation blocks in 0.094 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 2.3905109957E-02.
#   Reciprocal condition number of the overlap matrix is 6.8308697003E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         38      38
#    -------------------------
#     Total      38      38
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:  -113.79093964334359   -1.13791e+02   0.00000e+00
#    @DF-RKS iter   1:  -114.33526391655523   -5.44324e-01   1.34352e-02 DIIS
#    @DF-RKS iter   2:  -113.71318649830066    6.22077e-01   3.38865e-02 DIIS
#    @DF-RKS iter   3:  -114.43454342113105   -7.21357e-01   4.40170e-03 DIIS
#    @DF-RKS iter   4:  -114.44815530520023   -1.36119e-02   1.54316e-03 DIIS
#    @DF-RKS iter   5:  -114.44989829940677   -1.74299e-03   2.67782e-04 DIIS
#    @DF-RKS iter   6:  -114.44994706308438   -4.87637e-05   4.29642e-05 DIIS
#    @DF-RKS iter   7:  -114.44994815533855   -1.09225e-06   3.15753e-06 DIIS
#    @DF-RKS iter   8:  -114.44994816149340   -6.15485e-09   5.40241e-07 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =   15.9999994847 ; deviation = -5.153e-07
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -19.177397     2A    -10.336359     3A     -1.023601
#        4A     -0.596852     5A     -0.447123     6A     -0.433937
#        7A     -0.379609     8A     -0.273635
#
#     Virtual:
#
#        9A     -0.070688    10A     -0.011796    11A      0.081792
#       12A      0.190241    13A      0.396002    14A      0.448016
#       15A      0.467773    16A      0.528957    17A      0.586971
#       18A      0.718658    19A      0.883109    20A      0.919347
#       21A      0.963342    22A      1.047272    23A      1.158544
#       24A      1.252978    25A      1.254444    26A      1.434510
#       27A      1.474671    28A      1.505658    29A      1.598289
#       30A      1.680177    31A      1.888407    32A      2.070177
#       33A      2.167975    34A      2.625299    35A      2.668415
#       36A      2.931122    37A      3.085084    38A      3.275045
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     8 ]
#
#   @DF-RKS Final Energy:  -114.44994816149340
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             28.1078332598949423
#     One-Electron Energy =                -211.3471891647893699
#     Two-Electron Energy =                  80.5131080951127984
#     DFT Exchange-Correlation Energy =     -11.7237003517117540
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                       -114.4499481614933956
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:    -2.4853
#
#   Electronic Dipole Moment: [e a0]
#      X:     0.0000      Y:    -0.0000      Z:     1.6311
#
#   Dipole Moment: [e a0]
#      X:     0.0000      Y:    -0.0000      Z:    -0.8541     Total:     0.8541
#
#   Dipole Moment: [D]
#      X:     0.0000      Y:    -0.0000      Z:    -2.1710     Total:     2.1710
#
#
# *** tstop() called on 5536536a3eb7 at Fri Jun 23 04:22:57 2023
# Module time:
# 	user time   =       1.57 seconds =       0.03 minutes
# 	system time =       0.29 seconds =       0.00 minutes
# 	total time  =          2 seconds =       0.03 minutes
# Total time:
# 	user time   =      83.87 seconds =       1.40 minutes
# 	system time =      30.69 seconds =       0.51 minutes
# 	total time  =      31775 seconds =     529.58 minutes
#
#
#          ---------------------------------------------------------
#                          TDSCF excitation energies
#                  by Andrew M. James and Daniel G. A. Smith
#          ---------------------------------------------------------
#
#   ==> Options <==
#
#      Residual threshold  : 1.0000e-04
#      Initial guess       : denominators
#      Reference           : RHF
#      Solver type         : RPA (Hamiltonian)
#
#
#   ==> Requested Excitations <==
#
#       2 singlet states with A symmetry
#
#
#   ==> Seeking the lowest 2 singlet states with A symmetry
#
#                         Generalized Hamiltonian Solver
#                               By Andrew M. James
#
#   ==> Options <==
#
#     Max number of iterations        = 60
#     Eigenvector tolerance           = 1.0000e-04
#     Max number of expansion vectors = 400
#
#   => Iterations <=
#                               Max[D[value]]     Max[|R|]   # vectors
#   HamiltonianSolver iter   1:   2.48017e-01  1.52365e-01      8
#   HamiltonianSolver iter   2:   1.08941e-02  3.75721e-02     12
#   HamiltonianSolver iter   3:   3.01468e-04  6.86635e-03     16
#   HamiltonianSolver iter   4:   8.16672e-06  1.73658e-03     20
#   HamiltonianSolver iter   5:   4.46021e-07  4.86918e-04     22
#   HamiltonianSolver iter   6:   2.31448e-08  9.63848e-05     24      Converged
#
# ******************************************************************************************
# **********                               WARNING                                **********
# **********  Length-gauge rotatory strengths are **NOT** gauge-origin invariant  **********
# ******************************************************************************************
#
#                                     Excitation Energy         Total Energy        Oscillator Strength             Rotatory Strength
#      #   Sym: GS->ES (Trans)        au              eV              au          au (length)    au (velocity)    au (length)    au (velocity)
#     ---- -------------------- --------------- --------------- --------------- --------------- --------------- --------------- ---------------
#      1        A->A (1 A)       0.13049         3.55084        -114.31946       0.0000          0.0000          0.0000          0.0000
#      2        A->A (1 A)       0.23681         6.44400        -114.21314       0.1650          0.1374         -0.0000         -0.0000
#
#
#
# Contributing excitations and de-excitations
# Only contributions with coefficients > 1.00e-01 will be printed:
#
# Excited State    1 (1 A):   0.13049 au   349.17 nm f = 0.0000
#   Sums of squares: Xssq =  1.001792e+00; Yssq =  1.792420e-03; Xssq - Yssq =  1.000000e+00
#      8 ->  9    0.999215 (99.843%)
#
# Excited State    2 (1 A):   0.23681 au   192.40 nm f = 0.1650
#   Sums of squares: Xssq =  1.005715e+00; Yssq =  5.715167e-03; Xssq - Yssq =  1.000000e+00
#      5 -> 10   -0.123459 ( 1.524%)
#      8 -> 10    0.992570 (98.520%)
#
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
#
# *** tstart() called on 5536536a3eb7
# *** at Fri Jun 23 04:23:00 2023
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry C          line   138 file /usr/local/psi4/share/psi4/basis/cc-pvdz.gbs
#     atoms 2   entry O          line   198 file /usr/local/psi4/share/psi4/basis/cc-pvdz.gbs
#     atoms 3-4 entry H          line    22 file /usr/local/psi4/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C            0.000000000000     0.000000000000    -0.700494597316    12.000000000000
#          O            0.000000000000     0.000000000000     0.699505402684    15.994914619570
#          H            0.000000000000     1.177794549147    -1.380494597316     1.007825032230
#          H            0.000000000000    -1.177794549147    -1.380494597316     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      6.02896  B =      0.96021  C =      0.82829 [cm^-1]
#   Rotational constants: A = 180743.62258  B =  28786.51127  C =  24831.64704 [MHz]
#   Nuclear repulsion =   26.579220725595899
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 16
#   Nalpha       = 8
#   Nbeta        = 8
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-06
#   Density threshold  = 1.00e-06
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 18
#     Number of basis functions: 38
#     Number of Cartesian functions: 40
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 5.1.5
#     S. Lehtola, C. Steigemann, M. J. Oliveira, and M. A. Marques, SoftwareX 7, 1 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: B3LYP <=
#
#     B3LYP Hyb-GGA Exchange-Correlation Functional
#
#     P. J. Stephens, F. J. Devlin, C. F. Chabalowski, and M. J. Frisch, J. Phys. Chem. 98, 11623 (1994) (10.1021/j100096a001)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     0.0800   Slater exchange
#     0.7200         Becke 88
#
#    => Exact (HF) Exchange <=
#
#     0.2000               HF
#
#    => Correlation Functionals <=
#
#     0.1900   Vosko, Wilk & Nusair (VWN5_RPA)
#     0.8100   Lee, Yang & Parr
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_B3LYP:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =          87508
#     Total Blocks           =            720
#     Max Points             =            255
#     Max Functions          =             38
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1   entry C          line   121 file /usr/local/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 2   entry O          line   221 file /usr/local/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 3-4 entry H          line    51 file /usr/local/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.002 GiB; user supplied 0.273 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               279
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (CC-PVDZ AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 66
#     Number of basis functions: 186
#     Number of Cartesian functions: 212
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Cached 100.0% of DFT collocation blocks in 0.093 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 2.7267065680E-02.
#   Reciprocal condition number of the overlap matrix is 7.9555643008E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         38      38
#    -------------------------
#     Total      38      38
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:  -113.66545549360782   -1.13665e+02   0.00000e+00
#    @DF-RKS iter   1:  -114.29249629163638   -6.27041e-01   1.39270e-02 DIIS
#    @DF-RKS iter   2:  -113.20881877713202    1.08368e+00   4.19800e-02 DIIS
#    @DF-RKS iter   3:  -114.40177920448713   -1.19296e+00   4.33345e-03 DIIS
#    @DF-RKS iter   4:  -114.41360389515098   -1.18247e-02   2.41038e-03 DIIS
#    @DF-RKS iter   5:  -114.41771942861256   -4.11553e-03   4.76269e-04 DIIS
#    @DF-RKS iter   6:  -114.41786650197750   -1.47073e-04   1.15054e-04 DIIS
#    @DF-RKS iter   7:  -114.41787446337595   -7.96140e-06   1.05342e-05 DIIS
#    @DF-RKS iter   8:  -114.41787452629373   -6.29178e-08   1.31057e-06 DIIS
#    @DF-RKS iter   9:  -114.41787452739426   -1.10053e-09   1.31486e-07 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =   15.9999995834 ; deviation = -4.166e-07
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -19.177520     2A    -10.345023     3A     -0.978129
#        4A     -0.607754     5A     -0.435889     6A     -0.418722
#        7A     -0.353071     8A     -0.274014
#
#     Virtual:
#
#        9A     -0.091307    10A     -0.018673    11A      0.070653
#       12A      0.157971    13A      0.391011    14A      0.452149
#       15A      0.457769    16A      0.464988    17A      0.583939
#       18A      0.723351    19A      0.909259    20A      0.918016
#       21A      0.948422    22A      1.050415    23A      1.153138
#       24A      1.243154    25A      1.251811    26A      1.393466
#       27A      1.460658    28A      1.495742    29A      1.601013
#       30A      1.679111    31A      1.850634    32A      2.057333
#       33A      2.135135    34A      2.622351    35A      2.646798
#       36A      2.854962    37A      2.985299    38A      3.170940
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     8 ]
#
#   @DF-RKS Final Energy:  -114.41787452739426
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             26.5792207255958992
#     One-Electron Energy =                -208.4144220674094186
#     Two-Electron Energy =                  79.0939566067809636
#     DFT Exchange-Correlation Energy =     -11.6766297923616964
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                       -114.4178745273942610
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:    -2.5850
#
#   Electronic Dipole Moment: [e a0]
#      X:    -0.0000      Y:    -0.0000      Z:     1.5749
#
#   Dipole Moment: [e a0]
#      X:    -0.0000      Y:    -0.0000      Z:    -1.0100     Total:     1.0100
#
#   Dipole Moment: [D]
#      X:    -0.0000      Y:    -0.0000      Z:    -2.5673     Total:     2.5673
#
#
# *** tstop() called on 5536536a3eb7 at Fri Jun 23 04:23:02 2023
# Module time:
# 	user time   =       1.72 seconds =       0.03 minutes
# 	system time =       0.27 seconds =       0.00 minutes
# 	total time  =          2 seconds =       0.03 minutes
# Total time:
# 	user time   =      88.24 seconds =       1.47 minutes
# 	system time =      32.16 seconds =       0.54 minutes
# 	total time  =      31780 seconds =     529.67 minutes
#
#
#          ---------------------------------------------------------
#                          TDSCF excitation energies
#                  by Andrew M. James and Daniel G. A. Smith
#          ---------------------------------------------------------
#
#   ==> Options <==
#
#      Residual threshold  : 1.0000e-04
#      Initial guess       : denominators
#      Reference           : RHF
#      Solver type         : RPA (Hamiltonian)
#
#
#   ==> Requested Excitations <==
#
#       2 singlet states with A symmetry
#
#
#   ==> Seeking the lowest 2 singlet states with A symmetry
#
#                         Generalized Hamiltonian Solver
#                               By Andrew M. James
#
#   ==> Options <==
#
#     Max number of iterations        = 60
#     Eigenvector tolerance           = 1.0000e-04
#     Max number of expansion vectors = 400
#
#   => Iterations <=
#                               Max[D[value]]     Max[|R|]   # vectors
#   HamiltonianSolver iter   1:   2.33355e-01  1.38349e-01      8
#   HamiltonianSolver iter   2:   8.74264e-03  3.84630e-02     12
#   HamiltonianSolver iter   3:   2.80477e-04  6.74212e-03     16
#   HamiltonianSolver iter   4:   7.19306e-06  1.29194e-03     20
#   HamiltonianSolver iter   5:   2.06309e-07  2.60457e-04     22
#   HamiltonianSolver iter   6:   7.35929e-09  6.64354e-05     24      Converged
#
# ******************************************************************************************
# **********                               WARNING                                **********
# **********  Length-gauge rotatory strengths are **NOT** gauge-origin invariant  **********
# ******************************************************************************************
#
#                                     Excitation Energy         Total Energy        Oscillator Strength             Rotatory Strength
#      #   Sym: GS->ES (Trans)        au              eV              au          au (length)    au (velocity)    au (length)    au (velocity)
#     ---- -------------------- --------------- --------------- --------------- --------------- --------------- --------------- ---------------
#      1        A->A (1 A)       0.10933         2.97515        -114.30854       0.0000          0.0000          0.0000          0.0000
#      2        A->A (1 A)       0.22432         6.10417        -114.19355       0.1010          0.0802         -0.0000         -0.0000
#
#
#
# Contributing excitations and de-excitations
# Only contributions with coefficients > 1.00e-01 will be printed:
#
# Excited State    1 (1 A):   0.10933 au   416.73 nm f = 0.0000
#   Sums of squares: Xssq =  1.002713e+00; Yssq =  2.712979e-03; Xssq - Yssq =  1.000000e+00
#      8 ->  9    0.999973 (99.995%)
#
# ...
#                          TDSCF excitation energies
#                  by Andrew M. James and Daniel G. A. Smith
#          ---------------------------------------------------------
#
#   ==> Options <==
#
#      Residual threshold  : 1.0000e-04
#      Initial guess       : denominators
#      Reference           : RHF
#      Solver type         : RPA (Hamiltonian)
#
#
#   ==> Requested Excitations <==
#
#       2 singlet states with A symmetry
#
#
#   ==> Seeking the lowest 2 singlet states with A symmetry
#
#                         Generalized Hamiltonian Solver
#                               By Andrew M. James
#
#   ==> Options <==
#
#     Max number of iterations        = 60
#     Eigenvector tolerance           = 1.0000e-04
#     Max number of expansion vectors = 400
#
#   => Iterations <=
#                               Max[D[value]]     Max[|R|]   # vectors
#   HamiltonianSolver iter   1:   2.52837e-02  1.01579e-01      8
#   HamiltonianSolver iter   2:   1.99177e-03  5.92905e-03     12
#   HamiltonianSolver iter   3:   5.86535e-06  4.93118e-04     16
#   HamiltonianSolver iter   4:   6.27979e-08  7.39631e-05     18      Converged
#
# ******************************************************************************************
# **********                               WARNING                                **********
# **********  Length-gauge rotatory strengths are **NOT** gauge-origin invariant  **********
# ******************************************************************************************
#
#                                     Excitation Energy         Total Energy        Oscillator Strength             Rotatory Strength
#      #   Sym: GS->ES (Trans)        au              eV              au          au (length)    au (velocity)    au (length)    au (velocity)
#     ---- -------------------- --------------- --------------- --------------- --------------- --------------- --------------- ---------------
#      1        A->A (1 A)       0.01927         0.52436        -114.11946       0.0000          0.0021          0.0000          0.0000
#      2        A->A (1 A)       0.02467         0.67142        -114.11406       0.0000          0.0000          0.0000         -0.0000
#
#
#
# Contributing excitations and de-excitations
# Only contributions with coefficients > 1.00e-01 will be printed:
#
# Excited State    1 (1 A):   0.01927 au   2364.47 nm f = 0.0000
#   Sums of squares: Xssq =  1.246392e+00; Yssq =  2.463922e-01; Xssq - Yssq =  1.000000e+00
#      8 -> 10    1.111884 (123.629%)
#      8 <- 10   -0.492890 (24.294%)
#
# Excited State    2 (1 A):   0.02467 au   1846.60 nm f = 0.0000
#   Sums of squares: Xssq =  1.021860e+00; Yssq =  2.186035e-02; Xssq - Yssq =  1.000000e+00
#      8 ->  9    1.010715 (102.155%)
#      8 <-  9   -0.147014 ( 2.161%)
#
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
#
# *** tstart() called on 5536536a3eb7
# *** at Fri Jun 23 04:23:47 2023
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry C          line   138 file /usr/local/psi4/share/psi4/basis/cc-pvdz.gbs
#     atoms 2   entry O          line   198 file /usr/local/psi4/share/psi4/basis/cc-pvdz.gbs
#     atoms 3-4 entry H          line    22 file /usr/local/psi4/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C            0.000000000000     0.000000000000    -1.233470727155    12.000000000000
#          O            0.000000000000     0.000000000000     1.166529272845    15.994914619570
#          H            0.000000000000     1.177794549147    -1.913470727155     1.007825032230
#          H            0.000000000000    -1.177794549147    -1.913470727155     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      6.02896  B =      0.35562  C =      0.33581 [cm^-1]
#   Rotational constants: A = 180743.62258  B =  10661.29138  C =  10067.45535 [MHz]
#   Nuclear repulsion =   18.045044210234749
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 16
#   Nalpha       = 8
#   Nbeta        = 8
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-06
#   Density threshold  = 1.00e-06
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 18
#     Number of basis functions: 38
#     Number of Cartesian functions: 40
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 5.1.5
#     S. Lehtola, C. Steigemann, M. J. Oliveira, and M. A. Marques, SoftwareX 7, 1 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: B3LYP <=
#
#     B3LYP Hyb-GGA Exchange-Correlation Functional
#
#     P. J. Stephens, F. J. Devlin, C. F. Chabalowski, and M. J. Frisch, J. Phys. Chem. 98, 11623 (1994) (10.1021/j100096a001)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     0.0800   Slater exchange
#     0.7200         Becke 88
#
#    => Exact (HF) Exchange <=
#
#     0.2000               HF
#
#    => Correlation Functionals <=
#
#     0.1900   Vosko, Wilk & Nusair (VWN5_RPA)
#     0.8100   Lee, Yang & Parr
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_B3LYP:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =          87769
#     Total Blocks           =            722
#     Max Points             =            255
#     Max Functions          =             38
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1   entry C          line   121 file /usr/local/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 2   entry O          line   221 file /usr/local/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 3-4 entry H          line    51 file /usr/local/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.002 GiB; user supplied 0.283 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               289
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (CC-PVDZ AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 66
#     Number of basis functions: 186
#     Number of Cartesian functions: 212
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Cached 100.0% of DFT collocation blocks in 0.084 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 4.8816865254E-02.
#   Reciprocal condition number of the overlap matrix is 1.5351146151E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         38      38
#    -------------------------
#     Total      38      38
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:  -113.21159147286536   -1.13212e+02   0.00000e+00
#    @DF-RKS iter   1:  -113.50864293996027   -2.97051e-01   2.61418e-02 DIIS
#    @DF-RKS iter   2:  -105.97232314852982    7.53632e+00   6.01824e-02 DIIS
#    @DF-RKS iter   3:  -113.75862938659891   -7.78631e+00   1.79931e-02 DIIS
#    @DF-RKS iter   4:  -114.04250463602685   -2.83875e-01   1.00579e-02 DIIS
#    @DF-RKS iter   5:  -114.11943981127722   -7.69352e-02   1.71358e-03 DIIS
#    @DF-RKS iter   6:  -114.11644056706331    2.99924e-03   2.67029e-03 DIIS
#    @DF-RKS iter   7:  -114.11649968285489   -5.91158e-05   2.65042e-03 DIIS
#    @DF-RKS iter   8:  -114.11603358298392    4.66100e-04   2.75498e-03 DIIS
#    @DF-RKS iter   9:  -114.12199391134111   -5.96033e-03   7.44423e-04 DIIS
#    @DF-RKS iter  10:  -114.12236356913895   -3.69658e-04   4.96063e-04 DIIS
#    @DF-RKS iter  11:  -114.12257905860788   -2.15489e-04   9.59528e-05 DIIS
#    @DF-RKS iter  12:  -114.12258697258211   -7.91397e-06   3.08483e-06 DIIS
#    @DF-RKS iter  13:  -114.12258698579343   -1.32113e-08   4.90539e-07 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =   15.9999994213 ; deviation = -5.787e-07
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -19.172537     2A    -10.372046     3A     -0.840826
#        4A     -0.655536     5A     -0.431723     6A     -0.310162
#        7A     -0.255581     8A     -0.253712
#
#     Virtual:
#
#        9A     -0.176973    10A     -0.150589    11A     -0.020213
#       12A      0.036606    13A      0.372023    14A      0.424467
#       15A      0.442958    16A      0.499775    17A      0.528072
#       18A      0.710568    19A      0.900216    20A      0.909897
#       21A      0.922574    22A      0.983727    23A      1.066615
#       24A      1.075503    25A      1.218121    26A      1.249970
#       27A      1.436896    28A      1.487023    29A      1.524835
#       30A      1.592201    31A      1.673964    32A      2.045714
#       33A      2.093980    34A      2.619955    35A      2.635132
#       36A      2.647528    37A      2.651349    38A      2.658707
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     8 ]
#
#   @DF-RKS Final Energy:  -114.12258698579343
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             18.0450442102347495
#     One-Electron Energy =                -191.4333877654602816
#     Two-Electron Energy =                  70.8134558847144717
#     DFT Exchange-Correlation Energy =     -11.5476993152823777
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                       -114.1225869857934327
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:    -3.5820
#
#   Electronic Dipole Moment: [e a0]
#      X:    -0.0000      Y:    -0.0000      Z:     1.9432
#
#   Dipole Moment: [e a0]
#      X:    -0.0000      Y:    -0.0000      Z:    -1.6389     Total:     1.6389
#
#   Dipole Moment: [D]
#      X:    -0.0000      Y:    -0.0000      Z:    -4.1656     Total:     4.1656
#
#
# *** tstop() called on 5536536a3eb7 at Fri Jun 23 04:23:49 2023
# Module time:
# 	user time   =       2.11 seconds =       0.04 minutes
# 	system time =       0.30 seconds =       0.01 minutes
# 	total time  =          2 seconds =       0.03 minutes
# Total time:
# 	user time   =     132.66 seconds =       2.21 minutes
# 	system time =      45.52 seconds =       0.76 minutes
# 	total time  =      31827 seconds =     530.45 minutes
#
#
#          ---------------------------------------------------------
#                          TDSCF excitation energies
#                  by Andrew M. James and Daniel G. A. Smith
#          ---------------------------------------------------------
#
#   ==> Options <==
#
#      Residual threshold  : 1.0000e-04
#      Initial guess       : denominators
#      Reference           : RHF
#      Solver type         : RPA (Hamiltonian)
#
#
#   ==> Requested Excitations <==
#
#       2 singlet states with A symmetry
#
#
#   ==> Seeking the lowest 2 singlet states with A symmetry
#
#                         Generalized Hamiltonian Solver
#                               By Andrew M. James
#
#   ==> Options <==
#
#     Max number of iterations        = 60
#     Eigenvector tolerance           = 1.0000e-04
#     Max number of expansion vectors = 400
#
#   => Iterations <=
#                               Max[D[value]]     Max[|R|]   # vectors
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [55], in <module>
#      47 e, wfn = psi4.energy("b3lyp/cc-pVDZ", return_wfn=True, molecule=mol)
#      49 # calculate the excited-state energies and save them to a dictionary called 'res'
# ---> 50 res = tdscf_excitations(wfn, states=n_states, triplets = "NONE")
#      52 # parse the excitation energies from the 'res' dictionary
#      53 delta_e = [r["EXCITATION ENERGY"] for r in res]
#
# File /usr/local/psi4/lib/psi4/driver/procrouting/response/scf_response.py:699, in tdscf_excitations(wfn, states, triplets, tda, r_convergence, maxiter, guess, verbose, coeff_cutoff, tdm_print)
#     697 # singlets solve loop
#     698 if triplets == "NONE" or triplets == "ALSO":
# --> 699     res_1 = _solve_loop(wfn, ptype, solve_function, singlets_per_irrep, maxiter, restricted, "singlet")
#     700     _results.extend(res_1)
#     702 # triplets solve loop
#
# File /usr/local/psi4/lib/psi4/driver/procrouting/response/scf_response.py:305, in _solve_loop(wfn, ptype, solve_function, states_per_irrep, maxiter, restricted, spin_mult)
#     301 guess_ = engine.generate_guess(nstates * 4)
#     303 # ret = {"eigvals": ee, "eigvecs": (rvecs, rvecs), "stats": stats} (TDA)
#     304 # ret = {"eigvals": ee, "eigvecs": (rvecs, lvecs), "stats": stats} (RPA)
# --> 305 ret = solve_function(engine, nstates, guess_, maxiter)
#     307 # check whether all roots converged
#     308 if not ret["stats"][-1]["done"]:
#     309     # raise error
#
# File /usr/local/psi4/lib/psi4/driver/procrouting/response/scf_response.py:669, in tdscf_excitations.<locals>.rpa_solver(e, n, g, m)
#     668 def rpa_solver(e, n, g, m):
# --> 669     return solvers.hamiltonian_solver(engine=e,
#     670                                       nroot=n,
#     671                                       guess=g,
#     672                                       r_convergence=r_convergence,
#     673                                       max_ss_size=max_vecs_per_root * n,
#     674                                       verbose=verbose)
#
# File /usr/local/psi4/lib/psi4/driver/p4util/solvers.py:989, in hamiltonian_solver(engine, guess, nroot, r_convergence, max_ss_size, maxiter, verbose)
#     987 if np.any(H2_ss_val < 0.0):
#     988     msg = ("The H2 matrix is not Positive Definite. " "This means the reference state is not stable.")
# --> 989     raise RuntimeError(msg)
#     991 # Build H2^(1/2)
#     992 H2_ss_half = np.einsum("ik,k,jk->ij", H2_ss_vec, np.sqrt(H2_ss_val), H2_ss_vec, optimize=True)
#
# RuntimeError: The H2 matrix is not Positive Definite. This means the reference state is not stable.

# %%
print(mu_z)

# The first matrix includes the transition dipole moments of the transition between Eg and Ee1. 
# The second matrix include the transition dipole moments of the transition between Eg and Ee2.
# Out:
# [[1.23999166e-15 5.08507741e-15 6.63850684e-16 3.14758214e-15
#   9.17292174e-16 1.39549902e-14 1.08969786e-14 3.89494037e-16
#   4.71141570e-15 3.68149537e-15 1.93463953e-16 3.65127639e-15
#   2.11965302e-14 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00]
#  [7.64123867e-13 2.54236574e-12 3.14557661e-13 8.54795059e-13
#   5.85479391e-14 1.96555715e-13 8.20444075e-13 2.95175902e-14
#   1.56247837e-13 1.52942088e-13 1.41092471e-14 5.16387272e-14
#   5.69151708e-15 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00]]

# %%
# Take slices of information for Eg, Ee, and mu_eg only
Eg_array = np.copy(Es[0,:])
Ee1_array = np.copy(Es[1,:])
Ee2_array = np.copy(Es[2,:])
tdm1_array = np.copy(mu_z[0,:])
tdm2_array = np.copy(mu_z[1,:])

# %%
# fit all surfaces to a spline
# ==> Code to fit splines goes here! <== #
Eg_spline = InterpolatedUnivariateSpline(rs, Eg_array, k = 3)
Ee1_spline = InterpolatedUnivariateSpline(rs, Ee1_array, k = 3)
Ee2_spline = InterpolatedUnivariateSpline(rs, Ee2_array, k = 3)
mu1_spline = InterpolatedUnivariateSpline(rs, tdm1_array, k = 3)
mu2_spline = InterpolatedUnivariateSpline(rs, tdm2_array, k = 3)

# %%
R_val = 2.5

# ==> Code to evaluate Eg_spline, Ee1_spline, Ee2_spline, mu1_spline and mu2_spline at R = 2.5 Angstroms goes here! <== #
Eg_val = Eg_spline(R_val)
Ee1_val = Ee1_spline(R_val)
Ee2_val = Ee2_spline(R_val)
tdm1_val = mu1_spline(R_val)
tdm2_val = mu2_spline(R_val)

# %%
# conversion factor for au -> eV
au_to_eV = 27.211

# ==> Code to compute transition energy in atomic units and convert to eV goes here! <== #
transition_energy_au = Ee2_val - Eg_val
transition_energy_eV = transition_energy_au * au_to_eV
# Pre-written print the transition energies and check there values!
print(transition_energy_au)
print(transition_energy_eV)
# Out:
# -2.1094237467877974e-15
# -5.739952957384276e-14

# %%
def Rabi_Hamiltonian(A_value, omega_value, r_value, g_spline, e1_spline, e2_spline, tdm1_spline, tdm2_spline):
    """Function to compute the Rabi Hamiltonian

    Arguments
    ----------
    A_value : float
        fundamental coupling strength
        
    omega_value : float
        photon energy
        
    r_value : float
        value of the bondlength
        
    g_spline : scipy spline object
        spline that is fit to the ground-state potential energy surface
        
    e1_spline : scipy spline object
        spline that is fit to the excited-state 1 potential energy surface
    
    e2_spline : scipy spline object
        spline that is fit to the excited-state 2 potential energy surface
        
    tdm1_spline : scipy spline object
        spline that is fit to the transition dipole moment surface of e1
        
    tdm2_spline : scipy spline objec
        spline that is fit to the transition dipole moment surface of e2
        
    Returns
    -------
    H : numpy array
        5x5 Rabi Hamiltonian matrix
    """
    
    # initialize 5x5 Hamiltonian matrix
    H = np.zeros((5,5))
    
    H[0,0] = g_spline(r_value)
    H[1,1] = g_spline(r_value) + omega_value
    H[2,2] = e1_spline(r_value)
    H[3,3] = e1_spline(r_value) + omega_value
    H[4,4] = e2_spline(r_value)
    H[1,2] = tdm1_spline(r_value) * A_value
    H[2,1] = tdm1_spline(r_value) * A_value
    H[1,4] = tdm2_spline(r_value) * A_value
    H[4,1] = tdm2_spline(r_value) * A_value
    # return the matrix
    return H

# %%
A_value = 0.003

H_Rabi = Rabi_Hamiltonian(A_value, transition_energy_au, R_val, Eg_spline, Ee1_spline, Ee2_spline, mu1_spline, mu2_spline)

# %%
def polariton_surfaces(A_value, omega_value, r_values, g_spline, e1_spline, e2_spline, tdm1_spline, tdm2_spline):
    """Function to compute the lower- and upper-polariton potential energy surfaces

    Arguments
    ----------
    A_value : float
        fundamental coupling strength
        
    omega_value : float
        photon energy
        
    r_value : float
        value of the bondlength
        
    g_spline : scipy spline object
        spline that is fit to the ground-state potential energy surface
        
    e_spline : scipy spline object
        spline that is fit to the excited-state potential energy surface
        
    tdm_spline : scipy spline object
        spline that is fit to the transition dipole moment surface
        
    Returns
    -------
    E_LP_of_R : numpy array
        lower-polariton potential energy surface defined at each value of r_values
        
    E_UP_of_R : numpy array
        upper-polariton potential energy surface defined at each value of r_values
    """
    # initialize lp and up surfaces
    lp_surface = np.zeros_like(r_values)
    up_surface = np.zeros_like(r_values)
    
    # loop through r values, build Rabi Hamiltonian, diagonalize, and store!
    
    for i in range(0, len(r_values)):
        
        # if there is no coupling, then we don't need to diagonalize anything
        if A_value == 0:
            lp_surface[i] = g_spline(r_values[i]) + omega_value
            up_surface[i] = e2_spline(r_values[i])
        
        # otherwise build Hamiltonian and diagonalize
        else:
            # Build the Rabi Hamiltonian
            H = Rabi_Hamiltonian(A_value, omega_value, r_values[i], g_spline, e1_spline, e2_spline, tdm1_spline, tdm2_spline)
            
            # diagonalize
            vals, vecs = LA.eigh(H)
            
            # store lp and up values
            lp_surface[i] = vals[1]
            up_surface[i] = vals[2]
    
    # return the surfaces
    return lp_surface, up_surface

# %%
# run this cell to compute the polariton PES
lp_surface, up_surface = polariton_surfaces(A_value, transition_energy_au, rs, Eg_spline, Ee1_spline, Ee2_spline, mu1_spline, mu2_spline)

# %%
plt.figure()
plt.plot(rs, Eg_spline(rs)+transition_energy_au, "r--", label="Eg + $\hbar \omega$")
plt.plot(rs, Ee2_spline(rs), "b--", label="Ee2")
plt.plot(rs, lp_surface, "red", label="lower polariton")
plt.plot(rs, up_surface, "blue", label="upper polariton")
plt.grid(True)
plt.legend()
plt.ylim(-114.5, -114.1)
plt.xlim(1, 2.5)
# plt.show()
plt.savefig(F'zoomed.png', dpi = 300)

# %%
plt.figure()
plt.plot(rs, Eg_spline(rs)+transition_energy_au, "r--", label="Eg + $\hbar \omega$")
plt.plot(rs, Ee2_spline(rs), "b--", label="Ee2")
plt.plot(rs, lp_surface, "red", label="lower polariton")
plt.plot(rs, up_surface, "blue", label="upper polariton")
plt.grid(True)
plt.legend()
#plt.show()
plt.savefig(F'unzoomed.png', dpi = 300)
